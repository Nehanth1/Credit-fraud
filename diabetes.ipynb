# %%
import pandas as pd
db= pd.read_csv('C:\\Users\\Nehanth\\Desktop\\DSP\\diabetes.csv')
print(db.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(db.head(5))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(db.ndim)
# Out:
# 2

# %%
print(db.shape)
# Out:
# (768, 9)

# %%
print(db.axes)
# Out:
# [RangeIndex(start=0, stop=768, step=1), Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')]

# %%
print(db.loc[:,'BloodPressure'])
# Out:
# 0      72
# 1      66
# 2      64
# 3      66
# 4      40
#        ..
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: BloodPressure, Length: 768, dtype: int64

# %%
print(db.loc[:,'Age'])
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: Age, Length: 768, dtype: int64

# %%
newdb= db.loc[:,['Pregnancies', 'Glucose', 'Insulin', 'Age']]
print(newdb.head())
# Out:
#    Pregnancies  Glucose  Insulin  Age
# 0            6      148        0   50
# 1            1       85        0   31
# 2            8      183        0   32
# 3            1       89       94   21
# 4            0      137      168   33

# %%
file_name = "C:\\Users\\Nehanth\\Desktop\\DSP\\diabetes1.csv"
newdb. to_csv(file_name, sep=',', encoding='utf-8')

# %%
print(db.iloc[:,[2,3,4,5]])
# Out:
#      BloodPressure  SkinThickness  Insulin   BMI
# 0               72             35        0  33.6
# 1               66             29        0  26.6
# 2               64              0        0  23.3
# 3               66             23       94  28.1
# 4               40             35      168  43.1
# ..             ...            ...      ...   ...
# 763             76             48      180  32.9
# 764             70             27        0  36.8
# 765             72             23      112  26.2
# 766             60              0        0  30.1
# 767             70             31        0  30.4
#
# [768 rows x 4 columns]

# %%
db[db.Glucose>195]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 22             7      196             90              0        0  39.8
# 206            8      196             76             29      280  37.5
# 228            4      197             70             39      744  36.7
# 359            1      196             76             36      249  36.5
# 408            8      197             74              0        0  25.9
# 561            0      198             66             32      274  41.3
# 579            2      197             70             99        0  34.7
# 661            1      199             76             43        0  42.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 8                       0.158   53        1
# 22                      0.451   41        1
# 206                     0.605   57        1
# 228                     2.329   31        0
# ...

# %%
db[(db.Age>40) & (db.Glucose>195)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 22             7      196             90              0        0  39.8
# 206            8      196             76             29      280  37.5
# 579            2      197             70             99        0  34.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 8                       0.158   53        1
# 22                      0.451   41        1
# 206                     0.605   57        1
# 579                     0.575   62        1

# %%
db[(db.Pregnancies>5)&(db.Glucose>190)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 22             7      196             90              0        0  39.8
# 185            7      194             68             28        0  35.9
# 206            8      196             76             29      280  37.5
# 319            6      194             78              0        0  23.5
# 408            8      197             74              0        0  25.9
# 489            8      194             80              0        0  26.1
# 498            7      195             70             33      145  25.1
# 675            6      195             70              0        0  30.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 22                      0.451   41        1
# 185                     0.745   41        1
# 206                     0.605   57        1
# 319                     0.129   59        1
# 408                     1.191   39        1
# 489                     0.551   67        0
# ...

# %%
numbers = [1,0]
db[db.Outcome.isin(numbers)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
print(db.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
db.sort_index()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
db.sort_index(ascending=False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 767            1       93             70             31        0  30.4
# 766            1      126             60              0        0  30.1
# 765            5      121             72             23      112  26.2
# 764            2      122             70             27        0  36.8
# 763           10      101             76             48      180  32.9
# ..           ...      ...            ...            ...      ...   ...
# 4              0      137             40             35      168  43.1
# 3              1       89             66             23       94  28.1
# 2              8      183             64              0        0  23.3
# 1              1       85             66             29        0  26.6
# 0              6      148             72             35        0  33.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 767                     0.315   23        0
# ...

# %%
db.sort_values(by='Age')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 255            1      113             64             35        0  33.6
# 60             2       84              0              0        0   0.0
# 102            0      125             96              0        0  22.5
# 182            1        0             74             20       23  27.7
# 623            0       94             70             27      115  43.5
# ..           ...      ...            ...            ...      ...   ...
# 123            5      132             80              0        0  26.8
# 684            5      136             82              0        0   0.0
# 666            4      145             82             18        0  32.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 255                     0.543   21        1
# ...

# %%
db.sort_values(by="Age",ascending=False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459            9      134             74             33       60  25.9
# 453            2      119              0              0        0  19.6
# 666            4      145             82             18        0  32.5
# 123            5      132             80              0        0  26.8
# 684            5      136             82              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 240            1       91             64             24        0  29.2
# 136            0      100             70             26       50  30.8
# 382            1      109             60              8      182  25.4
# 392            1      131             64             14      415  23.7
# 271            2      108             62             32       56  25.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# ...

# %%
dbx=db[db.Age>80]
dbx.shape
# Out:
# (1, 9)

# %%
db.DiabetesPedigreeFunction.min()
# Out:
# 0.078

# %%
db.DiabetesPedigreeFunction.max()
# Out:
# 2.42

# %%
db.value_counts('Age')
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 40    13
# 43    13
# 46    13
# 39    12
# 35    10
# 52     8
# 44     8
# 50     8
# 51     8
# 58     7
# 54     6
# 47     6
# 53     5
# 60     5
# 49     5
# 57     5
# 48     5
# 66     4
# 62     4
# 63     4
# 55     4
# 59     3
# 56     3
# 65     3
# 67     3
# 61     2
# 69     2
# 64     1
# 68     1
# 70     1
# 72     1
# 81     1
# dtype: int64

# %%
db.groupby('Age').sum()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin     BMI  \
# Age
# 21            68     6824           4154           1219     4639  1752.5
# 22           112     7791           4588           1475     5363  2124.7
# 23            60     4240           2444            850     4485  1197.1
# 24            87     5423           2988           1193     4049  1498.2
# 25            85     5284           2864           1150     3979  1533.3
# 26            65     3901           2118            781     2999  1152.2
# 27            82     3689           2352            588     2020  1022.4
# 28           106     4197           2391            827     3311  1177.5
# 29            96     3694           1979            609     2575   972.7
# 30            76     2568           1362            397     1736   630.7
# 31            93     3047           1545            480     2668   816.4
# 32            71     1861           1121            291      573   517.1
# ...

# %%
db.groupby('Age').mean()
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Age
# 21      1.079365  108.317460      65.936508      19.349206   73.634921
# 22      1.555556  108.208333      63.722222      20.486111   74.486111
# 23      1.578947  111.578947      64.315789      22.368421  118.026316
# 24      1.891304  117.891304      64.956522      25.934783   88.021739
# 25      1.770833  110.083333      59.666667      23.958333   82.895833
# 26      1.969697  118.212121      64.181818      23.666667   90.878788
# 27      2.562500  115.281250      73.500000      18.375000   63.125000
# 28      3.028571  119.914286      68.314286      23.628571   94.600000
# 29      3.310345  127.379310      68.241379      21.000000   88.793103
# 30      3.619048  122.285714      64.857143      18.904762   82.666667
# 31      3.875000  126.958333      64.375000      20.000000  111.166667
# 32      4.437500  116.312500      70.062500      18.187500   35.812500
# ...

# %%
db.groupby('Age').sum().min()
# Out:
# Pregnancies                  2.000
# Glucose                     91.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                         19.600
# DiabetesPedigreeFunction     0.235
# Outcome                      0.000
# dtype: float64

# %%
db3=db.assign(AgeBMI=(db.loc[:,'Age']/db.loc[:,'BMI'])*0.5)
print(db3.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome    AgeBMI
# 0                     0.627   50        1  0.744048
# 1                     0.351   31        0  0.582707
# 2                     0.672   32        1  0.686695
# 3                     0.167   21        0  0.373665
# 4                     2.288   33        1  0.382831
